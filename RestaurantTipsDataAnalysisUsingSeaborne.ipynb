# %%
pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    -- ------------------------------------ 20.5/294.9 kB 165.2 kB/s eta 0:00:02
#    ---- ---------------------------------- 30.7/294.9 kB 217.9 kB/s eta 0:00:02
#    ------------ -------------------------- 92.2/294.9 kB 525.1 kB/s eta 0:00:01
#    -------------------------------------- - 286.7/294.9 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 1.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\anjal\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
tips = sns.load_dataset("tips")

# 1. Histogram of total bill
sns.histplot(tips["total_bill"], bins=20, kde=True, color="blue")
plt.title("Distribution of Total Bill")
plt.show()

# 2. Barplot of avg total bill by day
sns.barplot(x="day", y="total_bill", data=tips, palette="viridis")
plt.title("Average Bill by Day")
plt.show()

# 3. Boxplot of tips by gender
sns.boxplot(x="sex", y="tip", data=tips, palette="Set2")
plt.title("Tips by Gender")
plt.show()

# 4. Heatmap of correlations
sns.heatmap(tips.corr(numeric_only=True), annot=True, cmap="coolwarm", linewidths= 0.5)
plt.title("Correlation Heatmap")
plt.show()
# Out:
# C:\Users\anjal\AppData\Local\Temp\ipykernel_22512\1281029797.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="day", y="total_bill", data=tips, palette="viridis")
# C:\Users\anjal\AppData\Local\Temp\ipykernel_22512\1281029797.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="sex", y="tip", data=tips, palette="Set2")
